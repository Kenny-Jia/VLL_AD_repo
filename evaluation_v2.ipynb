# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Deep learning imports
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from sklearn.metrics import roc_curve, auc
from scipy.stats import pearsonr, spearmanr
import os
import matplotlib.cm as cm
# Out:
# 2025-04-11 02:22:24.291449: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-11 02:22:24.672761: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-11 02:22:24.802466: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744363344.964371  152104 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744363345.145490  152104 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1744363345.792137  152104 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744363345.792200  152104 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744363345.792205  152104 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744363345.792210  152104 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-11 02:22:25.871266: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# # Function to calculate reconstruction MSE
# def calculate_mse(model, electron_features, photon_features, vertices):
#     vertices = vertices.reshape(vertices.shape[0], 1, vertices.shape[1])
#     # Prepare inputs
#     inputs = {
#         'electron_input': electron_features,
#         'photon_input': photon_features,
#         'vertex_input': vertices
#     }
    
#     # Get model predictions
#     predictions = model.predict(inputs, batch_size=2048)
    
#     # Calculate MSE for electrons
#     electron_mse = np.mean(
#         np.square(predictions['electron_output'] - electron_features),
#         axis=(1, 2)  # Reduce over particle and feature dimensions
#     )
    
#     # Calculate MSE for photons
#     photon_mse = np.mean(
#         np.square(predictions['photon_output'] - photon_features),
#         axis=(1, 2)  # Reduce over particle and feature dimensions
#     )
    
#     # Total MSE (average of electron and photon MSEs)
#     total_mse = (electron_mse + photon_mse) / 2
    
#     return total_mse

# %%
# # Function to calculate reconstruction MAE
# def calculate_mae(model, electron_features, photon_features, vertices):
#     vertices = vertices.reshape(vertices.shape[0], 1, vertices.shape[1])
#     # Prepare inputs
#     inputs = {
#         'electron_input': electron_features,
#         'photon_input': photon_features,
#         'vertex_input': vertices
#     }
    
#     # Get model predictions
#     predictions = model.predict(inputs, batch_size=2048)
    
#     # Calculate MAE for electrons
#     electron_mae = np.mean(
#         np.absolute(predictions['electron_output'] - electron_features),
#         axis=(1, 2)  # Reduce over particle and feature dimensions
#     )
    
#     # Calculate MAE for photons
#     photon_mae = np.mean(
#         np.square(predictions['photon_output'] - photon_features),
#         axis=(1, 2)  # Reduce over particle and feature dimensions
#     )
    
#     # Total MAE (average of electron and photon MAEs)
#     total_mae = (electron_mae + photon_mae) / 2
    
#     return total_mae

# %%
def calculate_tanh_error(model, electron_features, photon_features, vertices):
    vertices = vertices.reshape(vertices.shape[0], 1, vertices.shape[1])
    
    # Prepare inputs
    inputs = {
        'electron_input': electron_features,
        'photon_input': photon_features,
        'vertex_input': vertices
    }
    
    # Get model predictions
    predictions = model.predict(inputs, batch_size=2048)
    
    # Calculate sigmoid of error for electrons
    electron_error = predictions['electron_output'] - electron_features
    electron_squared_error = np.square(electron_error)
    electron_squared_tanh_error = np.tanh(electron_squared_error)
    
    electron_mean_squared_tanh = np.mean(
        electron_squared_tanh_error,
        axis=(1, 2)  # Reduce over particle and feature dimensions
    )
    
    # Calculate sigmoid of error for photons
    photon_error = predictions['photon_output'] - photon_features
    photon_tanh_error = np.tanh(photon_error)
    photon_squared_tanh_error = np.square(photon_tanh_error)
    photon_mean_squared_tanh = np.mean(
        photon_squared_tanh_error,
        axis=(1, 2)  # Reduce over particle and feature dimensions
    )
    
    # Total mean of squared sigmoid of error (average of electron and photon values)
    total_mean_squared_tanh = (electron_mean_squared_tanh + photon_mean_squared_tanh) / 2
    
    return total_mean_squared_tanh

# %%
# Load data
# max_events = 100000
print("Loading test data...")
test_electron_features = np.load('test_data_e.npy')#[:max_events]
test_photon_features = np.load('test_data_p.npy')#[:max_events]
test_vertices = np.load('test_data_v.npy')#[:max_events]

print("Loading signal data...")
signal_electron_features = np.load('output_model_directory/signal_data_e_v2.npy')
signal_photon_features = np.load('output_model_directory/signal_data_p_v2.npy')
signal_vertices = np.load('output_model_directory/signal_data_v_v2.npy')
signal_models = np.load('output_model_directory/signal_models_v2.npy')
signal_job_ids = np.load('output_model_directory/signal_job_ids.npy')

print(f"Test data shapes: electrons {test_electron_features.shape}, photons {test_photon_features.shape}, vertices {test_vertices.shape}")
print(f"Signal data shapes: electrons {signal_electron_features.shape}, photons {signal_photon_features.shape}, vertices {signal_vertices.shape}")
print(f"Signal models shape: {signal_models.shape}")
print(f"Unique signal models: {np.unique(signal_models)}")
# Out:
# Loading test data...
# Loading signal data...
# Test data shapes: electrons (2483677, 4, 14), photons (2483677, 4, 13), vertices (2483677, 3)
# Signal data shapes: electrons (2080280, 4, 14), photons (2080280, 4, 13), vertices (2080280, 3)
# Signal models shape: (2080280,)
# Unique signal models: ['110_30_0p1ns' '110_30_0p5ns' '110_30_10ns' '110_30_2ns' '200_10_0p1ns'
#  '200_10_10ns' '200_10_2ns' '200_15_0p5ns' '200_15_10ns' '200_15_2ns'
#  '200_50_10ns' '200_50_2ns' '200_90_0p1ns' '200_90_0p5ns' '200_90_10ns'
#  '200_90_2ns' '400_100_0p1ns' '400_100_0p5ns' '400_100_10ns' '400_100_2ns'
#  '400_10_0p1ns' '400_10_0p5ns' '400_10_10ns' '400_15_0p1ns' '400_15_0p5ns'
#  '400_15_10ns' '400_190_0p1ns' '400_190_0p5ns' '400_190_10ns'
#  '600_10_0p1ns' '600_10_10ns' '600_10_2ns' '600_150_0p1ns' '600_150_0p5ns'
#  '600_150_10ns' '600_150_2ns' '600_15_0p1ns' '600_15_0p5ns' '600_15_10ns'
#  '600_15_2ns' '600_290_0p1ns' '600_290_0p5ns' '600_290_10ns' '600_290_2ns'
#  '60_25_0p5ns' '60_25_10ns' '60_25_2ns']

# %%
print(test_electron_features.shape)
# Out:
# (2483677, 4, 14)

# %%
def create_embedding_network(input_dim, hidden_dim, output_dim):
    """Create a deep embedding network."""
    return keras.Sequential([
        layers.Dense(hidden_dim),
        layers.LayerNormalization(),
        layers.LeakyReLU(negative_slope=0.1),
        layers.Dense(hidden_dim),
        layers.LayerNormalization(),
        layers.LeakyReLU(negative_slope=0.1),
        layers.Dense(output_dim)
    ])

class TransformerEncoderBlock(layers.Layer):
    """Transformer encoder block with multi-head attention."""
    def __init__(self, embedding_dim, num_heads=4, ff_dim_factor=4, dropout_rate=0.1):
        super().__init__()
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads,
            key_dim=embedding_dim // num_heads
        )
        self.ffn = keras.Sequential([
            layers.Dense(embedding_dim * ff_dim_factor),
            layers.LeakyReLU(negative_slope=0.1),
            layers.Dense(embedding_dim)
        ])
        self.layernorm1 = layers.LayerNormalization()
        self.layernorm2 = layers.LayerNormalization()

        self.dropout1 = layers.Dropout(dropout_rate)
        self.dropout2 = layers.Dropout(dropout_rate)
        
    def call(self, inputs):
        attention_output = self.attention(query=inputs, key=inputs, value=inputs)
        attention_output = self.dropout1(attention_output)
        out1 = self.layernorm1(inputs + attention_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output)
        return self.layernorm2(out1 + ffn_output)

class TransformerDecoderBlock(layers.Layer):
    """Transformer decoder block with multi-head self and cross attention."""
    def __init__(self, embedding_dim, num_heads=4, ff_dim_factor=4, dropout_rate=0.1):
        super().__init__()
        self.self_attention = layers.MultiHeadAttention(
            num_heads=num_heads,
            key_dim=embedding_dim // num_heads
        )
        self.cross_attention = layers.MultiHeadAttention(
            num_heads=num_heads,
            key_dim=embedding_dim // num_heads
        )
        self.ffn = keras.Sequential([
            layers.Dense(embedding_dim * ff_dim_factor),
            layers.LeakyReLU(negative_slope=0.1),
            layers.Dense(embedding_dim)
        ])
        self.layernorm1 = layers.LayerNormalization()
        self.layernorm2 = layers.LayerNormalization()
        self.layernorm3 = layers.LayerNormalization()

        self.dropout1 = layers.Dropout(dropout_rate)
        self.dropout2 = layers.Dropout(dropout_rate)
        self.dropout3 = layers.Dropout(dropout_rate)
        
    def call(self, inputs, encoder_outputs):
        # Self attention
        self_attention_output = self.self_attention(
            query=inputs,
            key=inputs,
            value=inputs
        )
        self_attention_output = self.dropout1(self_attention_output)
        out1 = self.layernorm1(inputs + self_attention_output)
        
        # Cross attention with encoder outputs
        cross_attention_output = self.cross_attention(
            query=out1,
            key=encoder_outputs,
            value=encoder_outputs
        )
        cross_attention_output = self.dropout2(cross_attention_output)
        out2 = self.layernorm2(out1 + cross_attention_output)
        
        # Feed-forward network
        ffn_output = self.ffn(out2)
        ffn_output = self.dropout3(ffn_output)
        return self.layernorm3(out2 + ffn_output)

# %%
electron_features_list = [
    'electron_E', 'electron_pt', 'electron_eta', 'electron_phi',
    'electron_time',
    'electron_d0', 'electron_z0', 'electron_dpt',
    'electron_nPIX', 'electron_nMissingLayers',
    'electron_chi2_over_nDoF',
    'electron_f1', 'electron_f3', 'electron_z'
]

photon_features_list = [
    'photon_E', 'photon_pt', 'photon_eta', 'photon_phi',
    'photon_time',
    'photon_maxEcell_E',
    'photon_f1', 'photon_f3', 'photon_r1', 'photon_r2',
    'photon_etas1', 'photon_phis1', 'photon_z'
]

# %%
class ParticleTransformer(keras.Model):
    """Complete transformer model for particle physics data."""
    def __init__(
        self,
        max_electrons=4,
        max_photons=4,
        electron_embedding_dim=14,
        photon_embedding_dim=13,
        vertex_embedding_dim=3,
        common_embedding_dim=31,
        num_encoder_layers=4,
        num_decoder_layers=4,
        num_heads=4
    ):
        super().__init__()
        
        # Input embeddings with different dimensions
        self.electron_embedding = create_embedding_network(
            len(electron_features_list),  # electron feature dim
            electron_embedding_dim,
            common_embedding_dim
        )
        self.photon_embedding = create_embedding_network(
            len(photon_features_list),  # photon feature dim
            photon_embedding_dim,
            common_embedding_dim
        )
        self.vertex_embedding = create_embedding_network(
            3,   # vertex feature dim
            vertex_embedding_dim,
            common_embedding_dim
        )
              
        # Transformer encoder layers
        self.encoder_layers = [
            TransformerEncoderBlock(common_embedding_dim, num_heads)
            for _ in range(num_encoder_layers)
        ]
        
        # Transformer decoder layers
        self.decoder_layers = [
            TransformerDecoderBlock(common_embedding_dim, num_heads)
            for _ in range(num_decoder_layers)
        ]
        
        # Output projection layers
        self.electron_reconstruction = keras.Sequential([
            layers.Dense(common_embedding_dim),
            layers.LeakyReLU(negative_slope=0.1),
            layers.Dense(common_embedding_dim),
            layers.LeakyReLU(negative_slope=0.1),
            layers.Dense(len(electron_features_list))  # electron features
        ])
        self.photon_reconstruction = keras.Sequential([
            layers.Dense(common_embedding_dim),
            layers.LeakyReLU(negative_slope=0.1),
            layers.Dense(common_embedding_dim),
            layers.LeakyReLU(negative_slope=0.1),
            layers.Dense(len(photon_features_list))  # photon features
        ])
        
    def encode_particles(self, electron_inputs, photon_inputs, vertex_inputs):
        # Embed particles
        e_embedded = self.electron_embedding(electron_inputs)
        p_embedded = self.photon_embedding(photon_inputs)
        v_embedded = self.vertex_embedding(vertex_inputs)
        
        # Combine embeddings
        combined = tf.concat([e_embedded, p_embedded, v_embedded], axis=1)
        
        # Pass through encoder layers
        encoded = combined
        intermediates = []
        for encoder_layer in self.encoder_layers:
            encoded = encoder_layer(encoded)
            intermediates.append(encoded)
            
        return encoded, intermediates
        
    def decode_particles(self, encoded, encoder_intermediates):
        decoded = encoded
        
        # Pass through decoder layers with corresponding encoder outputs
        for decoder_layer, encoder_output in zip(self.decoder_layers, encoder_intermediates):
            decoded = decoder_layer(decoded, encoder_output)
            
        return decoded
        
    def call(self, inputs):
        # Unpack inputs
        electron_inputs = inputs['electron_input']
        photon_inputs = inputs['photon_input']
        vertex_inputs = inputs['vertex_input']
        
        # Encode
        encoded, encoder_intermediates = self.encode_particles(
            electron_inputs, photon_inputs, vertex_inputs)
        
        # Decode
        decoded = self.decode_particles(encoded, encoder_intermediates)
        
        # Split and reconstruct
        e_len = electron_inputs.shape[1]
        electron_decoded = decoded[:, :e_len]
        photon_decoded = decoded[:, e_len:-1]
        
        # Output
        return {
            'electron_output': self.electron_reconstruction(electron_decoded),
            'photon_output': self.photon_reconstruction(photon_decoded)
        }

# %%
class ParticleDataGenerator(keras.utils.Sequence):
    """Data generator for particle physics events."""
    def __init__(self, data, batch_size=32, shuffle=True, **kwargs):
        super().__init__(**kwargs)
        self.electron_data, self.photon_data, self.vertex_data = data
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(self.vertex_data))
        self.on_epoch_end()
        
    def __len__(self):
        """Number of batches per epoch."""
        return len(self.indices) // self.batch_size
        
    def on_epoch_end(self):
        """Called at the end of every epoch."""
        if self.shuffle:
            np.random.shuffle(self.indices)
    
    def __getitem__(self, idx):
        """Get one batch of data."""
        batch_indices = self.indices[idx * self.batch_size:(idx + 1) * self.batch_size]
        
        # Prepare batch data
        x = {
            'electron_input': tf.convert_to_tensor(self.electron_data[batch_indices], dtype=tf.float32),
            'photon_input': tf.convert_to_tensor(self.photon_data[batch_indices], dtype=tf.float32),
            'vertex_input': tf.convert_to_tensor(self.vertex_data[batch_indices, np.newaxis, :], dtype=tf.float32)
        }
        
        y = {
            'electron_output': tf.convert_to_tensor(self.electron_data[batch_indices], dtype=tf.float32),
            'photon_output': tf.convert_to_tensor(self.photon_data[batch_indices], dtype=tf.float32)
        }
        
        return x, y

# %%
# Create the model with the correct dimensions
model = ParticleTransformer(
    max_electrons=4,
    max_photons=4,
    electron_embedding_dim=14,
    photon_embedding_dim=13,
    vertex_embedding_dim=3,
    common_embedding_dim=8,
    num_encoder_layers=4,
    num_decoder_layers=4,
    num_heads=4
)


# Create model with specified input shapes
electron_input = keras.Input(shape=(4, len(electron_features_list)), name='electron_input')
photon_input = keras.Input(shape=(4, len(photon_features_list)), name='photon_input')
vertex_input = keras.Input(shape=(1, 3), name='vertex_input')

outputs = model({
    'electron_input': electron_input,
    'photon_input': photon_input,
    'vertex_input': vertex_input
})

model = keras.Model(
    inputs={
        'electron_input': electron_input,
        'photon_input': photon_input,
        'vertex_input': vertex_input
    },
    outputs=outputs
)

# Load weights
model_path = 'particle_transformer_v2.keras'
# model_path = 'model_v1.weights.h5'
print(f"Loading weights from {model_path}...")
# Try first with load_weights
model.load_weights(model_path)
print("Weights loaded successfully.")
# Out:
# Loading weights from particle_transformer_v2.keras...
# Weights loaded successfully.

# %%
print(signal_electron_features[0])
# Out:
# [[-6.42765485e-01 -6.42874761e-01 -3.51502791e-03 -3.79454986e-08
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -5.93355029e-01 -3.00237085e-01 -6.35197532e-01 -5.99300735e-01
#   -4.19829004e-01  2.54144871e-04]
#  [-6.42765485e-01 -6.42874761e-01 -3.51502791e-03 -3.79454986e-08
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -5.93355029e-01 -3.00237085e-01 -6.35197532e-01 -5.99300735e-01
#   -4.19829004e-01  2.54144871e-04]
#  [-6.42765485e-01 -6.42874761e-01 -3.51502791e-03 -3.79454986e-08
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -5.93355029e-01 -3.00237085e-01 -6.35197532e-01 -5.99300735e-01
#   -4.19829004e-01  2.54144871e-04]
#  [-6.42765485e-01 -6.42874761e-01 -3.51502791e-03 -3.79454986e-08
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   -5.93355029e-01 -3.00237085e-01 -6.35197532e-01 -5.99300735e-01
#   -4.19829004e-01  2.54144871e-04]]

# %%
# Calculate anomaly scores
print("Calculating test data anomaly scores...")
test_scores = calculate_tanh_error(model, test_electron_features, test_photon_features, test_vertices)

print("Calculating signal data anomaly scores...")
signal_scores = calculate_tanh_error(model, signal_electron_features, signal_photon_features, signal_vertices)

# Create labels (0 for test/background, 1 for signal)
test_labels = np.zeros(len(test_scores))
signal_labels = np.ones(len(signal_scores))

# Combine scores and labels 
all_scores = np.concatenate([test_scores, signal_scores])
all_labels = np.concatenate([test_labels, signal_labels])

# Calculate overall ROC curve
fpr, tpr, thresholds = roc_curve(all_labels, all_scores)
roc_auc = auc(fpr, tpr)

print(f"Overall ROC AUC: {roc_auc:.6f}")
# Out:
# Calculating test data anomaly scores...
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 110s 89ms/step
# Calculating signal data anomaly scores...
# 1016/1016 ━━━━━━━━━━━━━━━━━━━━ 89s 87ms/step
# Overall ROC AUC: 0.828027

# %%
def display_highest_score_events(model, e_feats, p_feats, vertices, scores, n_events=2, dataset_name="Dataset"):
    """
    Display the highest-scoring events from a dataset with detailed error analysis.
    Shows both raw differences and tanh(diff²) for each feature with feature names.
    """
    # Define feature names
    electron_features_list = [
        'electron_E', 'electron_pt', 'electron_eta', 'electron_phi',
        'electron_time', 'electron_d0', 'electron_z0', 'electron_dpt',
        'electron_nPIX', 'electron_nMissingLayers', 
        'electron_chi2_over_nDoF', 'electron_f1', 'electron_f3', 'electron_z'
    ]
    
    photon_features_list = [
        'photon_E', 'photon_pt', 'photon_eta', 'photon_phi',
        'photon_time', 'photon_maxEcell_E', 'photon_f1', 'photon_f3', 
        'photon_r1', 'photon_r2', 'photon_etas1', 'photon_phis1', 'photon_z'
    ]
    
    # Find indices of highest scoring events
    top_indices = np.argsort(scores)[-n_events:][::-1]
    
    print(f"\n===== Top {n_events} highest scoring events from {dataset_name} =====")
    
    for i, idx in enumerate(top_indices):
        # Get input features for this event
        electron_input = e_feats[idx:idx+1]
        photon_input = p_feats[idx:idx+1]
        
        # Handle vertex input - reshape if necessary
        vertex_input = vertices[idx:idx+1]
        if len(vertex_input.shape) == 2:
            vertex_input = vertex_input.reshape(vertex_input.shape[0], 1, vertex_input.shape[1])
        
        # Get model prediction
        inputs = {
            'electron_input': electron_input,
            'photon_input': photon_input,
            'vertex_input': vertex_input
        }
        prediction = model.predict(inputs, verbose=0)
        
        # Print event information
        print(f"\nEvent {i+1} (index {idx}): Score = {scores[idx]:.6f}")
        
        # Print basic event properties
        if vertex_input.shape[1] == 1:
            print(f"  Vertex position: {vertex_input[0, 0]}")
        
        # Count total particles
        n_electrons = 4
        n_photons = 4
        print(f"  Number of electrons: {n_electrons}")
        print(f"  Number of photons: {n_photons}")
        
        # Print features of all particles with comparisons
        print("\n  ELECTRONS (actual vs predicted):")
        all_electron_errors = []
        
        for e_idx in range(4):
            print(f"  Electron #{e_idx+1}:")
            
            # Calculate tanh errors for this electron
            e_tanh_errors = []
            e_feature_errors = {}  # Store errors by feature name
            
            for feat_idx in range(min(len(electron_features_list), electron_input.shape[2])):
                feat_name = electron_features_list[feat_idx]
                actual = electron_input[0, e_idx, feat_idx]
                pred = prediction['electron_output'][0, e_idx, feat_idx]
                diff = actual - pred
                diff_squared = diff**2
                tanh_diff_squared = np.tanh(diff_squared)
                
                e_tanh_errors.append(tanh_diff_squared)
                e_feature_errors[feat_name] = tanh_diff_squared
                
                # Print feature details
                print(f"    {feat_name}: {actual:.4f} vs {pred:.4f} (diff: {diff:.4f}, tanh(diff²): {tanh_diff_squared:.4f})")
            
            # Add individual errors to the flat list
            all_electron_errors.extend(e_tanh_errors)
            
            # Find and print top 3 error features
            top_error_features = sorted(e_feature_errors.items(), key=lambda x: x[1], reverse=True)[:3]
            print(f"    Mean tanh(diff²) for this electron: {np.mean(e_tanh_errors):.4f}")
            print(f"    Top error features: " + ", ".join([f"{name} ({val:.4f})" for name, val in top_error_features]))
            print("")
        
        # Calculate overall electron error
        if all_electron_errors:
            avg_electron_error = np.mean(all_electron_errors)
            print(f"  Overall mean electron tanh(diff²): {avg_electron_error:.4f}")
        
        print("\n  PHOTONS (actual vs predicted):")
        all_photon_errors = []
        
        for p_idx in range(4):
            print(f"  Photon #{p_idx+1}:")
            
            # Calculate tanh errors for this photon
            p_tanh_errors = []
            p_feature_errors = {}  # Store errors by feature name
            
            for feat_idx in range(min(len(photon_features_list), photon_input.shape[2])):
                feat_name = photon_features_list[feat_idx]
                actual = photon_input[0, p_idx, feat_idx]
                pred = prediction['photon_output'][0, p_idx, feat_idx]
                diff = actual - pred
                diff_squared = diff**2
                tanh_diff_squared = np.tanh(diff_squared)
                
                p_tanh_errors.append(tanh_diff_squared)
                p_feature_errors[feat_name] = tanh_diff_squared
                
                # Print feature details
                print(f"    {feat_name}: {actual:.4f} vs {pred:.4f} (diff: {diff:.4f}, tanh(diff²): {tanh_diff_squared:.4f})")
            
            # Add individual errors to the flat list
            all_photon_errors.extend(p_tanh_errors)
            
            # Find and print top 3 error features
            top_error_features = sorted(p_feature_errors.items(), key=lambda x: x[1], reverse=True)[:3]
            print(f"    Mean tanh(diff²) for this photon: {np.mean(p_tanh_errors):.4f}")
            print(f"    Top error features: " + ", ".join([f"{name} ({val:.4f})" for name, val in top_error_features]))
            print("")
        
        # Calculate overall photon error
        if all_photon_errors:
            avg_photon_error = np.mean(all_photon_errors)
            print(f"  Overall mean photon tanh(diff²): {avg_photon_error:.4f}")
        
        # Calculate and print total event error
        all_errors = all_electron_errors + all_photon_errors
        if all_errors:
            total_avg_error = np.mean(all_errors)
            print(f"\n  Total event mean tanh(diff²): {total_avg_error:.4f}")
            print(f"  Compare with event score: {scores[idx]:.6f}")

# %%
# Usage:
# Display highest scoring background events
background_indices = np.where(all_labels == 0)[0]
background_only_scores = all_scores[background_indices]
display_highest_score_events(
    model,
    test_electron_features,
    test_photon_features,
    test_vertices,
    background_only_scores,
    n_events=3,
    dataset_name="Background"
)
# Out:
# ===== Top 3 highest scoring events from Background =====
#
# Event 1 (index 111740): Score = 0.356544
#   Vertex position: [-1.8678406  1.4569169  0.9011818]
#   Number of electrons: 4
#   Number of photons: 4
#
#   ELECTRONS (actual vs predicted):
#   Electron #1:
#     electron_E: 1.6217 vs 1.6962 (diff: -0.0745, tanh(diff²): 0.0055)
#     electron_pt: 1.5556 vs 1.6667 (diff: -0.1112, tanh(diff²): 0.0124)
#     electron_eta: 0.7914 vs 0.0174 (diff: 0.7740, tanh(diff²): 0.5364)
#     electron_phi: -0.9312 vs 0.0124 (diff: -0.9437, tanh(diff²): 0.7116)
#     electron_time: -0.1822 vs -1.2721 (diff: 1.0899, tanh(diff²): 0.8300)
#     electron_d0: 3.0021 vs 0.0010 (diff: 3.0010, tanh(diff²): 1.0000)
#     electron_z0: 23.9674 vs 25.2105 (diff: -1.2431, tanh(diff²): 0.9130)
#     electron_dpt: -0.6803 vs -0.1666 (diff: -0.5138, tanh(diff²): 0.2580)
#     electron_nPIX: -0.5934 vs 1.6244 (diff: -2.2178, tanh(diff²): 0.9999)
#     electron_nMissingLayers: -0.3002 vs 0.7451 (diff: -1.0454, tanh(diff²): 0.7979)
#     electron_chi2_over_nDoF: 1.8589 vs 1.6448 (diff: 0.2142, tanh(diff²): 0.0458)
#     electron_f1: 1.2900 vs 1.5435 (diff: -0.2536, tanh(diff²): 0.0642)
#     electron_f3: 2.5414 vs 1.1209 (diff: 1.4205, tanh(diff²): 0.9653)
#     electron_z: -0.0036 vs -0.0193 (diff: 0.0157, tanh(diff²): 0.0002)
#     Mean tanh(diff²) for this electron: 0.5100
#     Top error features: electron_d0 (1.0000), electron_nPIX (0.9999), electron_f3 (0.9653)
#
#   Electron #2:
#     electron_E: 1.4516 vs 2.7488 (diff: -1.2971, tanh(diff²): 0.9332)
#     electron_pt: 1.5307 vs 1.5248 (diff: 0.0059, tanh(diff²): 0.0000)
#     electron_eta: -0.0492 vs 1.7286 (diff: -1.7778, tanh(diff²): 0.9964)
#     electron_phi: -0.5912 vs 0.7383 (diff: -1.3294, tanh(diff²): 0.9433)
#     electron_time: -9999.0000 vs -10007.9004 (diff: 8.9004, tanh(diff²): 1.0000)
#     electron_d0: -0.0221 vs 1.4161 (diff: -1.4382, tanh(diff²): 0.9686)
#     electron_z0: 28.8449 vs 27.9468 (diff: 0.8980, tanh(diff²): 0.6676)
#     electron_dpt: -0.0341 vs -0.3746 (diff: 0.3405, tanh(diff²): 0.1154)
#     electron_nPIX: 1.6389 vs -1.4891 (diff: 3.1280, tanh(diff²): 1.0000)
#     electron_nMissingLayers: 2.2603 vs 2.0187 (diff: 0.2416, tanh(diff²): 0.0583)
#     electron_chi2_over_nDoF: 1.5181 vs 0.3615 (diff: 1.1566, tanh(diff²): 0.8711)
#     electron_f1: 2.2223 vs 1.6734 (diff: 0.5489, tanh(diff²): 0.2925)
#     electron_f3: -0.8255 vs 0.1689 (diff: -0.9943, tanh(diff²): 0.7568)
#     electron_z: 0.0011 vs -0.4955 (diff: 0.4966, tanh(diff²): 0.2417)
#     Mean tanh(diff²) for this electron: 0.6318
#     Top error features: electron_time (1.0000), electron_nPIX (1.0000), electron_eta (0.9964)
#
#   Electron #3:
#     electron_E: 1.2678 vs 2.7400 (diff: -1.4723, tanh(diff²): 0.9741)
#     electron_pt: 1.3750 vs 1.5541 (diff: -0.1790, tanh(diff²): 0.0320)
#     electron_eta: -0.0485 vs 1.7120 (diff: -1.7605, tanh(diff²): 0.9959)
#     electron_phi: -0.5909 vs 0.7313 (diff: -1.3223, tanh(diff²): 0.9412)
#     electron_time: -9999.0000 vs -10008.0000 (diff: 9.0000, tanh(diff²): 1.0000)
#     electron_d0: 0.0360 vs 1.3968 (diff: -1.3608, tanh(diff²): 0.9519)
#     electron_z0: 28.7512 vs 27.0426 (diff: 1.7086, tanh(diff²): 0.9942)
#     electron_dpt: -0.0762 vs -0.3785 (diff: 0.3022, tanh(diff²): 0.0911)
#     electron_nPIX: 1.6389 vs -1.4685 (diff: 3.1074, tanh(diff²): 1.0000)
#     electron_nMissingLayers: 2.2603 vs 2.0229 (diff: 0.2374, tanh(diff²): 0.0563)
#     electron_chi2_over_nDoF: 1.2455 vs 0.4128 (diff: 0.8327, tanh(diff²): 0.6001)
#     electron_f1: 2.9238 vs 1.6934 (diff: 1.2304, tanh(diff²): 0.9076)
#     electron_f3: -1.6051 vs 0.1485 (diff: -1.7536, tanh(diff²): 0.9957)
#     electron_z: 0.0005 vs -0.4815 (diff: 0.4820, tanh(diff²): 0.2282)
#     Mean tanh(diff²) for this electron: 0.6978
#     Top error features: electron_time (1.0000), electron_nPIX (1.0000), electron_eta (0.9959)
#
#   Electron #4:
#     electron_E: 1.2732 vs 2.7401 (diff: -1.4669, tanh(diff²): 0.9733)
#     electron_pt: 1.3674 vs 1.5538 (diff: -0.1863, tanh(diff²): 0.0347)
#     electron_eta: 0.1304 vs 1.7122 (diff: -1.5818, tanh(diff²): 0.9867)
#     electron_phi: -0.6405 vs 0.7314 (diff: -1.3720, tanh(diff²): 0.9547)
#     electron_time: -9999.0000 vs -10007.9980 (diff: 8.9980, tanh(diff²): 1.0000)
#     electron_d0: -0.0348 vs 1.3970 (diff: -1.4318, tanh(diff²): 0.9674)
#     electron_z0: 28.7473 vs 27.0534 (diff: 1.6939, tanh(diff²): 0.9936)
#     electron_dpt: -0.5900 vs -0.3784 (diff: -0.2115, tanh(diff²): 0.0447)
#     electron_nPIX: 1.6389 vs -1.4688 (diff: 3.1077, tanh(diff²): 1.0000)
#     electron_nMissingLayers: -0.3002 vs 2.0228 (diff: -2.3231, tanh(diff²): 1.0000)
#     electron_chi2_over_nDoF: 1.3473 vs 0.4123 (diff: 0.9351, tanh(diff²): 0.7036)
#     electron_f1: 2.6466 vs 1.6932 (diff: 0.9534, tanh(diff²): 0.7207)
#     electron_f3: -0.7985 vs 0.1487 (diff: -0.9472, tanh(diff²): 0.7149)
#     electron_z: -0.0107 vs -0.4816 (diff: 0.4709, tanh(diff²): 0.2182)
#     Mean tanh(diff²) for this electron: 0.7366
#     Top error features: electron_time (1.0000), electron_nPIX (1.0000), electron_nMissingLayers (1.0000)
#
#   Overall mean electron tanh(diff²): 0.6440
#
#   PHOTONS (actual vs predicted):
#   Photon #1:
#     photon_E: -0.5315 vs -0.5286 (diff: -0.0028, tanh(diff²): 0.0000)
#     photon_pt: -2.0395 vs -0.2839 (diff: -1.7555, tanh(diff²): 0.9958)
#     photon_eta: -1.0000 vs 0.7393 (diff: -1.7393, tanh(diff²): 0.9953)
#     photon_phi: -1.0000 vs 0.7355 (diff: -1.7355, tanh(diff²): 0.9952)
#     photon_time: 0.0000 vs -0.3274 (diff: 0.3274, tanh(diff²): 0.1068)
#     photon_maxEcell_E: -0.2618 vs -0.2734 (diff: 0.0116, tanh(diff²): 0.0001)
#     photon_f1: -0.4849 vs -0.4851 (diff: 0.0002, tanh(diff²): 0.0000)
#     photon_f3: -0.2673 vs -0.2825 (diff: 0.0151, tanh(diff²): 0.0002)
#     photon_r1: -0.5247 vs -0.5236 (diff: -0.0011, tanh(diff²): 0.0000)
#     photon_r2: -0.5239 vs -0.5366 (diff: 0.0127, tanh(diff²): 0.0002)
#     photon_etas1: 0.0004 vs 0.0083 (diff: -0.0079, tanh(diff²): 0.0001)
#     photon_phis1: 0.0010 vs 0.0056 (diff: -0.0046, tanh(diff²): 0.0000)
#     photon_z: 0.0002 vs -0.0034 (diff: 0.0036, tanh(diff²): 0.0000)
#     Mean tanh(diff²) for this photon: 0.2380
#     Top error features: photon_pt (0.9958), photon_eta (0.9953), photon_phi (0.9952)
#
#   Photon #2:
#     photon_E: -0.5315 vs -0.5158 (diff: -0.0157, tanh(diff²): 0.0002)
#     photon_pt: -0.0007 vs -0.2715 (diff: 0.2708, tanh(diff²): 0.0732)
#     photon_eta: 0.9951 vs 0.7332 (diff: 0.2620, tanh(diff²): 0.0685)
#     photon_phi: 0.9937 vs 0.7337 (diff: 0.2600, tanh(diff²): 0.0675)
#     photon_time: 0.0000 vs -0.2863 (diff: 0.2863, tanh(diff²): 0.0818)
#     photon_maxEcell_E: -0.2618 vs -0.2568 (diff: -0.0050, tanh(diff²): 0.0000)
#     photon_f1: -0.4849 vs -0.4796 (diff: -0.0052, tanh(diff²): 0.0000)
#     photon_f3: -0.2673 vs -0.2748 (diff: 0.0075, tanh(diff²): 0.0001)
#     photon_r1: -0.5247 vs -0.5075 (diff: -0.0172, tanh(diff²): 0.0003)
#     photon_r2: -0.5239 vs -0.5287 (diff: 0.0048, tanh(diff²): 0.0000)
#     photon_etas1: 0.0004 vs 0.0042 (diff: -0.0038, tanh(diff²): 0.0000)
#     photon_phis1: 0.0010 vs 0.0046 (diff: -0.0036, tanh(diff²): 0.0000)
#     photon_z: 0.0002 vs -0.0038 (diff: 0.0040, tanh(diff²): 0.0000)
#     Mean tanh(diff²) for this photon: 0.0224
#     Top error features: photon_time (0.0818), photon_pt (0.0732), photon_eta (0.0685)
#
#   Photon #3:
#     photon_E: -0.5315 vs -0.5158 (diff: -0.0157, tanh(diff²): 0.0002)
#     photon_pt: -0.0007 vs -0.2715 (diff: 0.2708, tanh(diff²): 0.0732)
#     photon_eta: 0.9951 vs 0.7332 (diff: 0.2620, tanh(diff²): 0.0685)
#     photon_phi: 0.9937 vs 0.7337 (diff: 0.2600, tanh(diff²): 0.0675)
#     photon_time: 0.0000 vs -0.2863 (diff: 0.2863, tanh(diff²): 0.0818)
#     photon_maxEcell_E: -0.2618 vs -0.2568 (diff: -0.0050, tanh(diff²): 0.0000)
#     photon_f1: -0.4849 vs -0.4796 (diff: -0.0052, tanh(diff²): 0.0000)
#     photon_f3: -0.2673 vs -0.2748 (diff: 0.0075, tanh(diff²): 0.0001)
#     photon_r1: -0.5247 vs -0.5075 (diff: -0.0172, tanh(diff²): 0.0003)
#     photon_r2: -0.5239 vs -0.5287 (diff: 0.0048, tanh(diff²): 0.0000)
#     photon_etas1: 0.0004 vs 0.0042 (diff: -0.0038, tanh(diff²): 0.0000)
#     photon_phis1: 0.0010 vs 0.0046 (diff: -0.0036, tanh(diff²): 0.0000)
#     photon_z: 0.0002 vs -0.0038 (diff: 0.0040, tanh(diff²): 0.0000)
#     Mean tanh(diff²) for this photon: 0.0224
#     Top error features: photon_time (0.0818), photon_pt (0.0732), photon_eta (0.0685)
#
#   Photon #4:
#     photon_E: -0.5315 vs -0.5158 (diff: -0.0157, tanh(diff²): 0.0002)
#     photon_pt: -0.0007 vs -0.2715 (diff: 0.2708, tanh(diff²): 0.0732)
#     photon_eta: 0.9951 vs 0.7332 (diff: 0.2620, tanh(diff²): 0.0685)
#     photon_phi: 0.9937 vs 0.7337 (diff: 0.2600, tanh(diff²): 0.0675)
#     photon_time: 0.0000 vs -0.2863 (diff: 0.2863, tanh(diff²): 0.0818)
#     photon_maxEcell_E: -0.2618 vs -0.2568 (diff: -0.0050, tanh(diff²): 0.0000)
#     photon_f1: -0.4849 vs -0.4796 (diff: -0.0052, tanh(diff²): 0.0000)
#     photon_f3: -0.2673 vs -0.2748 (diff: 0.0075, tanh(diff²): 0.0001)
#     photon_r1: -0.5247 vs -0.5075 (diff: -0.0172, tanh(diff²): 0.0003)
#     photon_r2: -0.5239 vs -0.5287 (diff: 0.0048, tanh(diff²): 0.0000)
#     photon_etas1: 0.0004 vs 0.0042 (diff: -0.0038, tanh(diff²): 0.0000)
#     photon_phis1: 0.0010 vs 0.0046 (diff: -0.0036, tanh(diff²): 0.0000)
#     photon_z: 0.0002 vs -0.0038 (diff: 0.0040, tanh(diff²): 0.0000)
#     Mean tanh(diff²) for this photon: 0.0224
#     Top error features: photon_time (0.0818), photon_pt (0.0732), photon_eta (0.0685)
#
#   Overall mean photon tanh(diff²): 0.0763
#
#   Total event mean tanh(diff²): 0.3707
#   Compare with event score: 0.356544
#
# Event 2 (index 566382): Score = 0.340869
#   Vertex position: [ 0.19500928 -0.23745707  1.352381  ]
#   Number of electrons: 4
#   Number of photons: 4
#
#   ELECTRONS (actual vs predicted):
#   Electron #1:
#     electron_E: 1.5720 vs 1.4268 (diff: 0.1452, tanh(diff²): 0.0211)
#     electron_pt: 1.5997 vs 1.5069 (diff: 0.0928, tanh(diff²): 0.0086)
#     electron_eta: 0.3183 vs -0.0280 (diff: 0.3463, tanh(diff²): 0.1193)
#     electron_phi: 0.5334 vs -0.0023 (diff: 0.5357, tanh(diff²): 0.2794)
#     electron_time: -0.0768 vs -1.0499 (diff: 0.9732, tanh(diff²): 0.7384)
#     electron_d0: 0.0009 vs -0.1250 (diff: 0.1259, tanh(diff²): 0.0159)
#     electron_z0: 43.9151 vs 44.8118 (diff: -0.8967, tanh(diff²): 0.6663)
#     electron_dpt: -0.0482 vs -0.1930 (diff: 0.1447, tanh(diff²): 0.0209)
#     electron_nPIX: 1.6389 vs 1.3837 (diff: 0.2552, tanh(diff²): 0.0650)
#     electron_nMissingLayers: -0.3002 vs 0.6813 (diff: -0.9816, tanh(diff²): 0.7458)
#     electron_chi2_over_nDoF: 1.5420 vs 1.5747 (diff: -0.0327, tanh(diff²): 0.0011)
#     electron_f1: 0.8493 vs 1.3803 (diff: -0.5310, tanh(diff²): 0.2747)
#     electron_f3: 0.4076 vs 0.8987 (diff: -0.4912, tanh(diff²): 0.2367)
#     electron_z: 0.0016 vs 0.0209 (diff: -0.0193, tanh(diff²): 0.0004)
#     Mean tanh(diff²) for this electron: 0.2281
#     Top error features: electron_nMissingLayers (0.7458), electron_time (0.7384), electron_z0 (0.6663)
#
#   Electron #2:
#     electron_E: 1.3806 vs 2.8177 (diff: -1.4371, tanh(diff²): 0.9684)
#     electron_pt: 1.4731 vs 1.2852 (diff: 0.1878, tanh(diff²): 0.0353)
#     electron_eta: 0.0226 vs 1.8681 (diff: -1.8456, tanh(diff²): 0.9978)
#     electron_phi: -0.3481 vs 0.7966 (diff: -1.1447, tanh(diff²): 0.8644)
#     electron_time: -9999.0000 vs -10005.3906 (diff: 6.3906, tanh(diff²): 1.0000)
#     electron_d0: -0.0191 vs 1.5713 (diff: -1.5904, tanh(diff²): 0.9874)
#     electron_z0: 43.8011 vs 35.5143 (diff: 8.2868, tanh(diff²): 1.0000)
#     electron_dpt: -0.0329 vs -0.3421 (diff: 0.3092, tanh(diff²): 0.0953)
#     electron_nPIX: 2.1969 vs -1.6637 (diff: 3.8606, tanh(diff²): 1.0000)
#     electron_nMissingLayers: 2.2603 vs 1.9794 (diff: 0.2810, tanh(diff²): 0.0788)
#     electron_chi2_over_nDoF: 1.2787 vs -0.0640 (diff: 1.3428, tanh(diff²): 0.9471)
#     electron_f1: 1.9273 vs 1.5048 (diff: 0.4225, tanh(diff²): 0.1766)
#     electron_f3: -0.5434 vs 0.3341 (diff: -0.8775, tanh(diff²): 0.6469)
#     electron_z: 0.0016 vs -0.6080 (diff: 0.6096, tanh(diff²): 0.3554)
#     Mean tanh(diff²) for this electron: 0.6538
#     Top error features: electron_time (1.0000), electron_z0 (1.0000), electron_nPIX (1.0000)
#
#   Electron #3:
#     electron_E: 1.3235 vs 2.8202 (diff: -1.4966, tanh(diff²): 0.9776)
#     electron_pt: 1.4052 vs 1.2764 (diff: 0.1289, tanh(diff²): 0.0166)
#     electron_eta: 0.1664 vs 1.8732 (diff: -1.7069, tanh(diff²): 0.9941)
#     electron_phi: -0.5939 vs 0.7987 (diff: -1.3926, tanh(diff²): 0.9595)
#     electron_time: -9999.0000 vs -10005.0977 (diff: 6.0977, tanh(diff²): 1.0000)
#     electron_d0: 0.0372 vs 1.5770 (diff: -1.5398, tanh(diff²): 0.9827)
#     electron_z0: 44.1197 vs 35.7921 (diff: 8.3276, tanh(diff²): 1.0000)
#     electron_dpt: -0.2253 vs -0.3409 (diff: 0.1156, tanh(diff²): 0.0134)
#     electron_nPIX: 1.6389 vs -1.6701 (diff: 3.3090, tanh(diff²): 1.0000)
#     electron_nMissingLayers: -0.3002 vs 1.9779 (diff: -2.2781, tanh(diff²): 0.9999)
#     electron_chi2_over_nDoF: 1.8616 vs -0.0797 (diff: 1.9413, tanh(diff²): 0.9989)
#     electron_f1: 3.0730 vs 1.4986 (diff: 1.5745, tanh(diff²): 0.9860)
#     electron_f3: -0.5639 vs 0.3401 (diff: -0.9040, tanh(diff²): 0.6736)
#     electron_z: 0.0011 vs -0.6121 (diff: 0.6132, tanh(diff²): 0.3592)
#     Mean tanh(diff²) for this electron: 0.7830
#     Top error features: electron_time (1.0000), electron_z0 (1.0000), electron_nPIX (1.0000)
#
#   Electron #4:
#     electron_E: 1.2855 vs 2.8204 (diff: -1.5349, tanh(diff²): 0.9822)
#     electron_pt: 1.3701 vs 1.2756 (diff: 0.0945, tanh(diff²): 0.0089)
#     electron_eta: 0.1670 vs 1.8736 (diff: -1.7067, tanh(diff²): 0.9941)
#     electron_phi: -0.5919 vs 0.7989 (diff: -1.3908, tanh(diff²): 0.9591)
#     electron_time: -9999.0000 vs -10005.0762 (diff: 6.0762, tanh(diff²): 1.0000)
#     electron_d0: -0.0966 vs 1.5775 (diff: -1.6741, tanh(diff²): 0.9927)
#     electron_z0: 44.0059 vs 35.8144 (diff: 8.1915, tanh(diff²): 1.0000)
#     electron_dpt: -0.3737 vs -0.3408 (diff: -0.0329, tanh(diff²): 0.0011)
#     electron_nPIX: 1.6389 vs -1.6706 (diff: 3.3095, tanh(diff²): 1.0000)
#     electron_nMissingLayers: -0.3002 vs 1.9778 (diff: -2.2780, tanh(diff²): 0.9999)
#     electron_chi2_over_nDoF: 1.8934 vs -0.0810 (diff: 1.9744, tanh(diff²): 0.9992)
#     electron_f1: 3.1715 vs 1.4981 (diff: 1.6734, tanh(diff²): 0.9926)
#     electron_f3: 1.3781 vs 0.3406 (diff: 1.0375, tanh(diff²): 0.7919)
#     electron_z: 0.0011 vs -0.6125 (diff: 0.6136, tanh(diff²): 0.3597)
#     Mean tanh(diff²) for this electron: 0.7915
#     Top error features: electron_time (1.0000), electron_z0 (1.0000), electron_nPIX (1.0000)
#
#   Overall mean electron tanh(diff²): 0.6141
#
#   PHOTONS (actual vs predicted):
#   Photon #1:
#     photon_E: -0.5315 vs -0.5212 (diff: -0.0102, tanh(diff²): 0.0001)
#     photon_pt: -2.0395 vs -0.2714 (diff: -1.7681, tanh(diff²): 0.9962)
#     photon_eta: -1.0000 vs 0.7315 (diff: -1.7315, tanh(diff²): 0.9950)
#     photon_phi: -1.0000 vs 0.7329 (diff: -1.7329, tanh(diff²): 0.9951)
#     photon_time: 0.0000 vs -0.2282 (diff: 0.2282, tanh(diff²): 0.0520)
#     photon_maxEcell_E: -0.2618 vs -0.2599 (diff: -0.0019, tanh(diff²): 0.0000)
#     photon_f1: -0.4849 vs -0.4853 (diff: 0.0004, tanh(diff²): 0.0000)
#     photon_f3: -0.2673 vs -0.2723 (diff: 0.0050, tanh(diff²): 0.0000)
#     photon_r1: -0.5247 vs -0.5126 (diff: -0.0122, tanh(diff²): 0.0001)
#     photon_r2: -0.5239 vs -0.5328 (diff: 0.0089, tanh(diff²): 0.0001)
#     photon_etas1: 0.0004 vs 0.0028 (diff: -0.0024, tanh(diff²): 0.0000)
#     photon_phis1: 0.0010 vs 0.0050 (diff: -0.0040, tanh(diff²): 0.0000)
#     photon_z: 0.0002 vs -0.0023 (diff: 0.0025, tanh(diff²): 0.0000)
#     Mean tanh(diff²) for this photon: 0.2337
#     Top error features: photon_pt (0.9962), photon_phi (0.9951), photon_eta (0.9950)
#
#   Photon #2:
#     photon_E: -0.5315 vs -0.5121 (diff: -0.0194, tanh(diff²): 0.0004)
#     photon_pt: -0.0007 vs -0.2679 (diff: 0.2671, tanh(diff²): 0.0712)
#     photon_eta: 0.9951 vs 0.7314 (diff: 0.2637, tanh(diff²): 0.0694)
#     photon_phi: 0.9937 vs 0.7331 (diff: 0.2606, tanh(diff²): 0.0678)
#     photon_time: 0.0000 vs -0.2710 (diff: 0.2710, tanh(diff²): 0.0733)
#     photon_maxEcell_E: -0.2618 vs -0.2519 (diff: -0.0098, tanh(diff²): 0.0001)
#     photon_f1: -0.4849 vs -0.4780 (diff: -0.0069, tanh(diff²): 0.0000)
#     photon_f3: -0.2673 vs -0.2725 (diff: 0.0052, tanh(diff²): 0.0000)
#     photon_r1: -0.5247 vs -0.5029 (diff: -0.0219, tanh(diff²): 0.0005)
#     photon_r2: -0.5239 vs -0.5262 (diff: 0.0024, tanh(diff²): 0.0000)
#     photon_etas1: 0.0004 vs 0.0030 (diff: -0.0026, tanh(diff²): 0.0000)
#     photon_phis1: 0.0010 vs 0.0042 (diff: -0.0032, tanh(diff²): 0.0000)
#     photon_z: 0.0002 vs -0.0039 (diff: 0.0041, tanh(diff²): 0.0000)
#     Mean tanh(diff²) for this photon: 0.0218
#     Top error features: photon_time (0.0733), photon_pt (0.0712), photon_eta (0.0694)
#
#   Photon #3:
#     photon_E: -0.5315 vs -0.5121 (diff: -0.0194, tanh(diff²): 0.0004)
#     photon_pt: -0.0007 vs -0.2679 (diff: 0.2671, tanh(diff²): 0.0712)
#     photon_eta: 0.9951 vs 0.7314 (diff: 0.2637, tanh(diff²): 0.0694)
#     photon_phi: 0.9937 vs 0.7331 (diff: 0.2606, tanh(diff²): 0.0678)
#     photon_time: 0.0000 vs -0.2710 (diff: 0.2710, tanh(diff²): 0.0733)
#     photon_maxEcell_E: -0.2618 vs -0.2519 (diff: -0.0098, tanh(diff²): 0.0001)
#     photon_f1: -0.4849 vs -0.4780 (diff: -0.0069, tanh(diff²): 0.0000)
#     photon_f3: -0.2673 vs -0.2725 (diff: 0.0052, tanh(diff²): 0.0000)
#     photon_r1: -0.5247 vs -0.5029 (diff: -0.0219, tanh(diff²): 0.0005)
#     photon_r2: -0.5239 vs -0.5262 (diff: 0.0024, tanh(diff²): 0.0000)
#     photon_etas1: 0.0004 vs 0.0030 (diff: -0.0026, tanh(diff²): 0.0000)
#     photon_phis1: 0.0010 vs 0.0042 (diff: -0.0032, tanh(diff²): 0.0000)
#     photon_z: 0.0002 vs -0.0039 (diff: 0.0041, tanh(diff²): 0.0000)
#     Mean tanh(diff²) for this photon: 0.0218
#     Top error features: photon_time (0.0733), photon_pt (0.0712), photon_eta (0.0694)
#
#   Photon #4:
#     photon_E: -0.5315 vs -0.5121 (diff: -0.0194, tanh(diff²): 0.0004)
#     photon_pt: -0.0007 vs -0.2679 (diff: 0.2671, tanh(diff²): 0.0712)
#     photon_eta: 0.9951 vs 0.7314 (diff: 0.2637, tanh(diff²): 0.0694)
#     photon_phi: 0.9937 vs 0.7331 (diff: 0.2606, tanh(diff²): 0.0678)
#     photon_time: 0.0000 vs -0.2710 (diff: 0.2710, tanh(diff²): 0.0733)
#     photon_maxEcell_E: -0.2618 vs -0.2519 (diff: -0.0098, tanh(diff²): 0.0001)
#     photon_f1: -0.4849 vs -0.4780 (diff: -0.0069, tanh(diff²): 0.0000)
#     photon_f3: -0.2673 vs -0.2725 (diff: 0.0052, tanh(diff²): 0.0000)
#     photon_r1: -0.5247 vs -0.5029 (diff: -0.0219, tanh(diff²): 0.0005)
#     photon_r2: -0.5239 vs -0.5262 (diff: 0.0024, tanh(diff²): 0.0000)
#     photon_etas1: 0.0004 vs 0.0030 (diff: -0.0026, tanh(diff²): 0.0000)
#     photon_phis1: 0.0010 vs 0.0042 (diff: -0.0032, tanh(diff²): 0.0000)
#     photon_z: 0.0002 vs -0.0039 (diff: 0.0041, tanh(diff²): 0.0000)
#     Mean tanh(diff²) for this photon: 0.0218
#     Top error features: photon_time (0.0733), photon_pt (0.0712), photon_eta (0.0694)
#
#   Overall mean photon tanh(diff²): 0.0748
#
#   Total event mean tanh(diff²): 0.3544
#   Compare with event score: 0.340869
#
# Event 3 (index 2248712): Score = 0.330106
#   Vertex position: [ 0.86838514 -0.49761072  0.9242796 ]
#   Number of electrons: 4
#   Number of photons: 4
#
#   ELECTRONS (actual vs predicted):
#   Electron #1:
#     electron_E: 1.7014 vs 2.7642 (diff: -1.0628, tanh(diff²): 0.8109)
#     electron_pt: 1.6906 vs 1.4720 (diff: 0.2186, tanh(diff²): 0.0477)
#     electron_eta: 0.8173 vs 1.7612 (diff: -0.9439, tanh(diff²): 0.7119)
#     electron_phi: 0.0880 vs 0.7520 (diff: -0.6640, tanh(diff²): 0.4144)
#     electron_time: -9999.0000 vs -10008.1748 (diff: 9.1748, tanh(diff²): 1.0000)
#     electron_d0: -0.0004 vs 1.4502 (diff: -1.4507, tanh(diff²): 0.9707)
#     electron_z0: 30.5544 vs 29.6872 (diff: 0.8672, tanh(diff²): 0.6364)
#     electron_dpt: -0.8614 vs -0.3671 (diff: -0.4943, tanh(diff²): 0.2396)
#     electron_nPIX: 0.5228 vs -1.5299 (diff: 2.0526, tanh(diff²): 0.9996)
#     electron_nMissingLayers: -0.3002 vs 2.0087 (diff: -2.3090, tanh(diff²): 1.0000)
#     electron_chi2_over_nDoF: 1.9454 vs 0.2652 (diff: 1.6801, tanh(diff²): 0.9930)
#     electron_f1: 1.3056 vs 1.6348 (diff: -0.3292, tanh(diff²): 0.1080)
#     electron_f3: 1.7481 vs 0.2055 (diff: 1.5425, tanh(diff²): 0.9830)
#     electron_z: 0.0023 vs -0.5199 (diff: 0.5223, tanh(diff²): 0.2662)
#     Mean tanh(diff²) for this electron: 0.6558
#     Top error features: electron_time (1.0000), electron_nMissingLayers (1.0000), electron_nPIX (0.9996)
#
#   Electron #2:
#     electron_E: 1.4201 vs 1.6069 (diff: -0.1868, tanh(diff²): 0.0349)
#     electron_pt: 1.5055 vs 1.6153 (diff: -0.1098, tanh(diff²): 0.0121)
#     electron_eta: 0.0294 vs 0.0019 (diff: 0.0275, tanh(diff²): 0.0008)
#     electron_phi: -0.9057 vs 0.0074 (diff: -0.9131, tanh(diff²): 0.6825)
#     electron_time: -0.0966 vs -1.2426 (diff: 1.1459, tanh(diff²): 0.8651)
#     electron_d0: -0.0116 vs -0.0429 (diff: 0.0313, tanh(diff²): 0.0010)
#     electron_z0: 30.5482 vs 32.2246 (diff: -1.6764, tanh(diff²): 0.9928)
#     electron_dpt: -0.0024 vs -0.1760 (diff: 0.1736, tanh(diff²): 0.0301)
#     electron_nPIX: 1.0808 vs 1.5450 (diff: -0.4642, tanh(diff²): 0.2122)
#     electron_nMissingLayers: 2.2603 vs 0.7244 (diff: 1.5359, tanh(diff²): 0.9823)
#     electron_chi2_over_nDoF: 1.5176 vs 1.6247 (diff: -0.1071, tanh(diff²): 0.0115)
#     electron_f1: 2.0638 vs 1.4910 (diff: 0.5729, tanh(diff²): 0.3169)
#     electron_f3: 0.0903 vs 1.0467 (diff: -0.9564, tanh(diff²): 0.7234)
#     electron_z: 0.0005 vs -0.0055 (diff: 0.0061, tanh(diff²): 0.0000)
#     Mean tanh(diff²) for this electron: 0.3475
#     Top error features: electron_z0 (0.9928), electron_nMissingLayers (0.9823), electron_time (0.8651)
#
#   Electron #3:
#     electron_E: 1.5474 vs 2.7848 (diff: -1.2373, tanh(diff²): 0.9106)
#     electron_pt: 1.4022 vs 1.4011 (diff: 0.0011, tanh(diff²): 0.0000)
#     electron_eta: 0.8127 vs 1.8016 (diff: -0.9889, tanh(diff²): 0.7522)
#     electron_phi: 0.1292 vs 0.7688 (diff: -0.6396, tanh(diff²): 0.3877)
#     electron_time: -9999.0000 vs -10007.9395 (diff: 8.9395, tanh(diff²): 1.0000)
#     electron_d0: -13.8545 vs 1.4964 (diff: -15.3509, tanh(diff²): 1.0000)
#     electron_z0: 35.7451 vs 31.8869 (diff: 3.8582, tanh(diff²): 1.0000)
#     electron_dpt: -0.8388 vs -0.3577 (diff: -0.4811, tanh(diff²): 0.2274)
#     electron_nPIX: 0.5228 vs -1.5804 (diff: 2.1032, tanh(diff²): 0.9997)
#     electron_nMissingLayers: 2.2603 vs 1.9981 (diff: 0.2623, tanh(diff²): 0.0687)
#     electron_chi2_over_nDoF: 1.9077 vs 0.1406 (diff: 1.7671, tanh(diff²): 0.9961)
#     electron_f1: 3.1497 vs 1.5858 (diff: 1.5638, tanh(diff²): 0.9851)
#     electron_f3: 1.4319 vs 0.2543 (diff: 1.1775, tanh(diff²): 0.8824)
#     electron_z: -0.0134 vs -0.5535 (diff: 0.5401, tanh(diff²): 0.2837)
#     Mean tanh(diff²) for this electron: 0.6781
#     Top error features: electron_time (1.0000), electron_d0 (1.0000), electron_z0 (1.0000)
#
#   Electron #4:
#     electron_E: 1.5289 vs 2.8445 (diff: -1.3156, tanh(diff²): 0.9391)
#     electron_pt: 1.3775 vs 1.1877 (diff: 0.1898, tanh(diff²): 0.0360)
#     electron_eta: 0.7921 vs 1.9228 (diff: -1.1307, tanh(diff²): 0.8561)
#     electron_phi: 0.0859 vs 0.8193 (diff: -0.7334, tanh(diff²): 0.4913)
#     electron_time: -9999.0000 vs -10001.2197 (diff: 2.2197, tanh(diff²): 0.9999)
#     electron_d0: 0.2675 vs 1.6337 (diff: -1.3662, tanh(diff²): 0.9533)
#     electron_z0: 55.0917 vs 38.5317 (diff: 16.5600, tanh(diff²): 1.0000)
#     electron_dpt: 0.7116 vs -0.3292 (diff: 1.0408, tanh(diff²): 0.7944)
#     electron_nPIX: 1.6389 vs -1.7325 (diff: 3.3714, tanh(diff²): 1.0000)
#     electron_nMissingLayers: 2.2603 vs 1.9638 (diff: 0.2965, tanh(diff²): 0.0877)
#     electron_chi2_over_nDoF: 1.5056 vs -0.2347 (diff: 1.7403, tanh(diff²): 0.9953)
#     electron_f1: 1.3092 vs 1.4370 (diff: -0.1279, tanh(diff²): 0.0163)
#     electron_f3: 4.1402 vs 0.4006 (diff: 3.7396, tanh(diff²): 1.0000)
#     electron_z: 0.0493 vs -0.6537 (diff: 0.7030, tanh(diff²): 0.4575)
#     Mean tanh(diff²) for this electron: 0.6876
#     Top error features: electron_z0 (1.0000), electron_f3 (1.0000), electron_nPIX (1.0000)
#
#   Overall mean electron tanh(diff²): 0.5923
#
#   PHOTONS (actual vs predicted):
#   Photon #1:
#     photon_E: -0.5315 vs -0.5231 (diff: -0.0084, tanh(diff²): 0.0001)
#     photon_pt: -2.0395 vs -0.2733 (diff: -1.7661, tanh(diff²): 0.9961)
#     photon_eta: -1.0000 vs 0.7325 (diff: -1.7325, tanh(diff²): 0.9951)
#     photon_phi: -1.0000 vs 0.7332 (diff: -1.7332, tanh(diff²): 0.9951)
#     photon_time: 0.0000 vs -0.2368 (diff: 0.2368, tanh(diff²): 0.0560)
#     photon_maxEcell_E: -0.2618 vs -0.2625 (diff: 0.0007, tanh(diff²): 0.0000)
#     photon_f1: -0.4849 vs -0.4859 (diff: 0.0011, tanh(diff²): 0.0000)
#     photon_f3: -0.2673 vs -0.2736 (diff: 0.0063, tanh(diff²): 0.0000)
#     photon_r1: -0.5247 vs -0.5150 (diff: -0.0098, tanh(diff²): 0.0001)
#     photon_r2: -0.5239 vs -0.5339 (diff: 0.0100, tanh(diff²): 0.0001)
#     photon_etas1: 0.0004 vs 0.0035 (diff: -0.0031, tanh(diff²): 0.0000)
#     photon_phis1: 0.0010 vs 0.0052 (diff: -0.0042, tanh(diff²): 0.0000)
#     photon_z: 0.0002 vs -0.0023 (diff: 0.0025, tanh(diff²): 0.0000)
#     Mean tanh(diff²) for this photon: 0.2340
#     Top error features: photon_pt (0.9961), photon_phi (0.9951), photon_eta (0.9951)
#
#   Photon #2:
#     photon_E: -0.5315 vs -0.5139 (diff: -0.0176, tanh(diff²): 0.0003)
#     photon_pt: -0.0007 vs -0.2698 (diff: 0.2690, tanh(diff²): 0.0723)
#     photon_eta: 0.9951 vs 0.7324 (diff: 0.2627, tanh(diff²): 0.0689)
#     photon_phi: 0.9937 vs 0.7334 (diff: 0.2603, tanh(diff²): 0.0677)
#     photon_time: 0.0000 vs -0.2791 (diff: 0.2791, tanh(diff²): 0.0777)
#     photon_maxEcell_E: -0.2618 vs -0.2544 (diff: -0.0074, tanh(diff²): 0.0001)
#     photon_f1: -0.4849 vs -0.4786 (diff: -0.0063, tanh(diff²): 0.0000)
#     photon_f3: -0.2673 vs -0.2738 (diff: 0.0065, tanh(diff²): 0.0000)
#     photon_r1: -0.5247 vs -0.5052 (diff: -0.0196, tanh(diff²): 0.0004)
#     photon_r2: -0.5239 vs -0.5273 (diff: 0.0034, tanh(diff²): 0.0000)
#     photon_etas1: 0.0004 vs 0.0037 (diff: -0.0033, tanh(diff²): 0.0000)
#     photon_phis1: 0.0010 vs 0.0043 (diff: -0.0033, tanh(diff²): 0.0000)
#     photon_z: 0.0002 vs -0.0039 (diff: 0.0041, tanh(diff²): 0.0000)
#     Mean tanh(diff²) for this photon: 0.0221
#     Top error features: photon_time (0.0777), photon_pt (0.0723), photon_eta (0.0689)
#
#   Photon #3:
#     photon_E: -0.5315 vs -0.5139 (diff: -0.0176, tanh(diff²): 0.0003)
#     photon_pt: -0.0007 vs -0.2698 (diff: 0.2690, tanh(diff²): 0.0723)
#     photon_eta: 0.9951 vs 0.7324 (diff: 0.2627, tanh(diff²): 0.0689)
#     photon_phi: 0.9937 vs 0.7334 (diff: 0.2603, tanh(diff²): 0.0677)
#     photon_time: 0.0000 vs -0.2791 (diff: 0.2791, tanh(diff²): 0.0777)
#     photon_maxEcell_E: -0.2618 vs -0.2544 (diff: -0.0074, tanh(diff²): 0.0001)
#     photon_f1: -0.4849 vs -0.4786 (diff: -0.0063, tanh(diff²): 0.0000)
#     photon_f3: -0.2673 vs -0.2738 (diff: 0.0065, tanh(diff²): 0.0000)
#     photon_r1: -0.5247 vs -0.5052 (diff: -0.0196, tanh(diff²): 0.0004)
#     photon_r2: -0.5239 vs -0.5273 (diff: 0.0034, tanh(diff²): 0.0000)
#     photon_etas1: 0.0004 vs 0.0037 (diff: -0.0033, tanh(diff²): 0.0000)
#     photon_phis1: 0.0010 vs 0.0043 (diff: -0.0033, tanh(diff²): 0.0000)
#     photon_z: 0.0002 vs -0.0039 (diff: 0.0041, tanh(diff²): 0.0000)
#     Mean tanh(diff²) for this photon: 0.0221
#     Top error features: photon_time (0.0777), photon_pt (0.0723), photon_eta (0.0689)
#
#   Photon #4:
#     photon_E: -0.5315 vs -0.5139 (diff: -0.0176, tanh(diff²): 0.0003)
#     photon_pt: -0.0007 vs -0.2698 (diff: 0.2690, tanh(diff²): 0.0723)
#     photon_eta: 0.9951 vs 0.7324 (diff: 0.2627, tanh(diff²): 0.0689)
#     photon_phi: 0.9937 vs 0.7334 (diff: 0.2603, tanh(diff²): 0.0677)
#     photon_time: 0.0000 vs -0.2791 (diff: 0.2791, tanh(diff²): 0.0777)
#     photon_maxEcell_E: -0.2618 vs -0.2544 (diff: -0.0074, tanh(diff²): 0.0001)
#     photon_f1: -0.4849 vs -0.4786 (diff: -0.0063, tanh(diff²): 0.0000)
#     photon_f3: -0.2673 vs -0.2738 (diff: 0.0065, tanh(diff²): 0.0000)
#     photon_r1: -0.5247 vs -0.5052 (diff: -0.0196, tanh(diff²): 0.0004)
#     photon_r2: -0.5239 vs -0.5273 (diff: 0.0034, tanh(diff²): 0.0000)
#     photon_etas1: 0.0004 vs 0.0037 (diff: -0.0033, tanh(diff²): 0.0000)
#     photon_phis1: 0.0010 vs 0.0043 (diff: -0.0033, tanh(diff²): 0.0000)
#     photon_z: 0.0002 vs -0.0039 (diff: 0.0041, tanh(diff²): 0.0000)
#     Mean tanh(diff²) for this photon: 0.0221
#     Top error features: photon_time (0.0777), photon_pt (0.0723), photon_eta (0.0689)
#
#   Overall mean photon tanh(diff²): 0.0751
#
#   Total event mean tanh(diff²): 0.3433
#   Compare with event score: 0.330106

# %%
# Create a dictionary to store per-model results
model_results = {}

# Get list of unique models
unique_models = np.unique(signal_models)
print(f"Analyzing {len(unique_models)} unique signal models...")

# Perform analysis for each model separately
for model_name in unique_models:
    # Get mask for this model
    model_mask = signal_models == model_name
    
    # Get scores for this model only
    model_scores = signal_scores[model_mask]
    
    # Create model-specific labels
    model_labels = np.ones(len(model_scores))
    
    # Combine with test data for ROC calculation
    model_all_scores = np.concatenate([test_scores, model_scores])
    model_all_labels = np.concatenate([test_labels, model_labels])
    
    # Calculate model-specific ROC
    model_fpr, model_tpr, model_thresholds = roc_curve(model_all_labels, model_all_scores)
    model_roc_auc = auc(model_fpr, model_tpr)
    
    # Parse parameters from model name
    parts = model_name.split('_')
    mass1 = int(parts[0])
    mass2 = int(parts[1])
    
    # Handle lifetime format (convert 0p1ns to 0.1)
    lifetime_str = parts[2].replace('ns', '')
    lifetime = float(lifetime_str.replace('p', '.'))
    
    # Calculate statistics for this model
    model_results[model_name] = {
        'num_events': np.sum(model_mask),
        'mean_score': np.mean(model_scores),
        'scores': model_scores,
        'roc_auc': model_roc_auc,
        'mass1': mass1,
        'mass2': mass2,
        'lifetime': lifetime
    }
    
    print(f"Model {model_name}: {np.sum(model_mask)} events, ROC AUC = {model_roc_auc:.6f}")
# Out:
# Analyzing 47 unique signal models...
# Model 110_30_0p1ns: 83352 events, ROC AUC = 0.905667
# Model 110_30_0p5ns: 77710 events, ROC AUC = 0.800937
# Model 110_30_10ns: 16744 events, ROC AUC = 0.518721
# Model 110_30_2ns: 26963 events, ROC AUC = 0.636567
# Model 200_10_0p1ns: 79792 events, ROC AUC = 0.812358
# Model 200_10_10ns: 3367 events, ROC AUC = 0.409756
# Model 200_10_2ns: 15817 events, ROC AUC = 0.456628
# Model 200_15_0p5ns: 64946 events, ROC AUC = 0.631167
# Model 200_15_10ns: 6487 events, ROC AUC = 0.385941
# Model 200_15_2ns: 13917 events, ROC AUC = 0.457220
# Model 200_50_10ns: 23953 events, ROC AUC = 0.491757
# Model 200_50_2ns: 68060 events, ROC AUC = 0.656464
# Model 200_90_0p1ns: 93391 events, ROC AUC = 0.942960
# Model 200_90_0p5ns: 88904 events, ROC AUC = 0.906061
# Model 200_90_10ns: 17922 events, ROC AUC = 0.649461
# Model 200_90_2ns: 74156 events, ROC AUC = 0.806719
# Model 400_100_0p1ns: 98098 events, ROC AUC = 0.954001
# Model 400_100_0p5ns: 48167 events, ROC AUC = 0.906239
# Model 400_100_10ns: 27189 events, ROC AUC = 0.547073
# Model 400_100_2ns: 39461 events, ROC AUC = 0.746522
# Model 400_10_0p1ns: 30635 events, ROC AUC = 0.756367
# Model 400_10_0p5ns: 23454 events, ROC AUC = 0.597311
# Model 400_10_10ns: 1330 events, ROC AUC = 0.510337
# Model 400_15_0p1ns: 81408 events, ROC AUC = 0.823798
# Model 400_15_0p5ns: 42089 events, ROC AUC = 0.619633
# Model 400_15_10ns: 2953 events, ROC AUC = 0.470639
# Model 400_190_0p1ns: 97922 events, ROC AUC = 0.959843
# Model 400_190_0p5ns: 95187 events, ROC AUC = 0.945629
# Model 400_190_10ns: 45501 events, ROC AUC = 0.753643
# Model 600_10_0p1ns: 44230 events, ROC AUC = 0.707015
# Model 600_10_10ns: 849 events, ROC AUC = 0.543746
# Model 600_10_2ns: 3516 events, ROC AUC = 0.566761
# Model 600_150_0p1ns: 99232 events, ROC AUC = 0.966526
# Model 600_150_0p5ns: 49187 events, ROC AUC = 0.936792
# Model 600_150_10ns: 16484 events, ROC AUC = 0.629260
# Model 600_150_2ns: 41329 events, ROC AUC = 0.805343
# Model 600_15_0p1ns: 31751 events, ROC AUC = 0.788475
# Model 600_15_0p5ns: 12858 events, ROC AUC = 0.643315
# Model 600_15_10ns: 862 events, ROC AUC = 0.524516
# Model 600_15_2ns: 3817 events, ROC AUC = 0.568704
# Model 600_290_0p1ns: 99090 events, ROC AUC = 0.968951
# Model 600_290_0p5ns: 97394 events, ROC AUC = 0.965314
# Model 600_290_10ns: 25272 events, ROC AUC = 0.832768
# Model 600_290_2ns: 86363 events, ROC AUC = 0.929145
# Model 60_25_0p5ns: 55057 events, ROC AUC = 0.803152
# Model 60_25_10ns: 5340 events, ROC AUC = 0.606080
# Model 60_25_2ns: 18774 events, ROC AUC = 0.681859

# %%
model_params = []
for model_name, results in model_results.items():
    model_params.append({
        'name': model_name,
        'mass1': results['mass1'],
        'mass2': results['mass2'],
        'lifetime': results['lifetime'],
        'roc_auc': results['roc_auc'],
        'mean_score': results['mean_score'],
        'num_events': results['num_events']
    })

# Convert to DataFrame for easier analysis
params_df = pd.DataFrame(model_params)

# %%
# Plot 1: Distribution of anomaly scores by lifetime
plt.figure(figsize=(14, 8))

# Plot background distribution first
plt.hist(test_scores, bins=50, alpha=0.5, label='Background', density=True, color='gray')

# Group models by lifetime
lifetime_groups = {}
for model_name, results in model_results.items():
    lifetime = results['lifetime']
    if lifetime not in lifetime_groups:
        lifetime_groups[lifetime] = []
    lifetime_groups[lifetime].extend(results['scores'])

# Use a colormap to distinguish different lifetimes
colors = cm.rainbow(np.linspace(0, 1, len(lifetime_groups)))

# Plot score distribution for each lifetime
for (lifetime, scores), color in zip(lifetime_groups.items(), colors):
    if len(scores) > 10:
        plt.hist(
            scores, 
            bins=50, 
            alpha=0.4, 
            density=True,
            color=color,
            label=f'Lifetime = {lifetime}ns'
        )

plt.xlabel('Anomaly Score')
plt.ylabel('Density')
plt.title('Distribution of Anomaly Scores by Lifetime')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Plot 2: Distribution of anomaly scores by mass combination
plt.figure(figsize=(14, 8))

# Plot background distribution first
plt.hist(test_scores, bins=50, alpha=0.5, label='Background', density=True, color='gray')

# Group models by mass combination
mass_groups = {}
for model_name, results in model_results.items():
    mass_key = f"{results['mass1']}_{results['mass2']}"
    if mass_key not in mass_groups:
        mass_groups[mass_key] = []
    mass_groups[mass_key].extend(results['scores'])

# Use a colormap to distinguish different mass combinations
colors = cm.rainbow(np.linspace(0, 1, len(mass_groups)))

# Plot score distribution for each mass combination
for (mass_key, scores), color in zip(mass_groups.items(), colors):
    if len(scores) > 10:
        plt.hist(
            scores, 
            bins=50, 
            alpha=0.4, 
            density=True,
            color=color,
            label=f'Mass = {mass_key} GeV'
        )

plt.xlabel('Anomaly Score')
plt.ylabel('Density')
plt.title('Distribution of Anomaly Scores by Mass Combination')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Plot 3: Distribution of anomaly scores by model
plt.figure(figsize=(14, 8))

# Plot background distribution first
plt.hist(test_scores, bins=50, alpha=0.5, label='Background', density=True, color='gray')

# Use a colormap to distinguish different models
colors = cm.rainbow(np.linspace(0, 1, len(model_results)))

# Plot score distribution for each model
for (model_name, results), color in zip(model_results.items(), colors):
    scores = results['scores']
    if len(scores) > 10:
        plt.hist(
            scores, 
            bins=50, 
            alpha=0.3, 
            density=True,
            color=color,
            label=model_name
        )

plt.xlabel('Anomaly Score')
plt.ylabel('Density')
plt.title('Distribution of Anomaly Scores by Model')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
def calculate_feature_correlations(scores, e_feats, p_feats, method='pearson'):
    """
    Calculate correlations between anomaly scores and each feature.
    
    Parameters:
    -----------
    scores: numpy array of anomaly scores
    e_feats: electron features (shape: [n_events, n_electrons, n_features])
    p_feats: photon features (shape: [n_events, n_photons, n_features])
    method: correlation method ('pearson' or 'spearman')
    
    Returns:
    --------
    Dictionary with correlations for electron and photon features
    """
    results = {
        'electron': [],
        'photon': []
    }
    
    # Define correlation function based on method
    if method == 'pearson':
        corr_func = pearsonr
    else:  # spearman
        corr_func = spearmanr
    
    # Calculate for electron features
    for feat_idx in range(e_feats.shape[2]):
        # Average feature value across all electrons in each event
        feat_values = np.mean(e_feats[:, :, feat_idx], axis=1)
        # Only consider events where feature exists (non-zero)
        mask = ~np.isnan(feat_values) & (np.abs(feat_values) > 1e-10)
        
        if np.sum(mask) > 10:  # Need enough data points
            corr, p_value = corr_func(scores[mask], feat_values[mask])
            results['electron'].append({
                'feature_idx': feat_idx,
                'correlation': corr,
                'p_value': p_value
            })
    
    # Calculate for photon features
    for feat_idx in range(p_feats.shape[2]):
        # Average feature value across all photons in each event
        feat_values = np.mean(p_feats[:, :, feat_idx], axis=1)
        # Only consider events where feature exists (non-zero)
        mask = ~np.isnan(feat_values) & (np.abs(feat_values) > 1e-10)
        
        if np.sum(mask) > 10:  # Need enough data points
            corr, p_value = corr_func(scores[mask], feat_values[mask])
            results['photon'].append({
                'feature_idx': feat_idx,
                'correlation': corr,
                'p_value': p_value
            })
    
    return results

def plot_correlation_results(correlation_results, e_feat_names=None, p_feat_names=None):
    """
    Plot correlation results between scores and features.
    
    Parameters:
    -----------
    correlation_results: Output from calculate_feature_correlations
    e_feat_names: List of electron feature names (optional)
    p_feat_names: List of photon feature names (optional)
    """
    # Prepare data for plotting
    e_corrs = pd.DataFrame(correlation_results['electron'])
    p_corrs = pd.DataFrame(correlation_results['photon'])
    
    # Add feature names if provided
    if e_feat_names:
        e_corrs['feature_name'] = e_corrs['feature_idx'].apply(lambda x: e_feat_names[x])
    else:
        e_corrs['feature_name'] = e_corrs['feature_idx'].apply(lambda x: f"Electron_{x}")
        
    if p_feat_names:
        p_corrs['feature_name'] = p_corrs['feature_idx'].apply(lambda x: p_feat_names[x])
    else:
        p_corrs['feature_name'] = p_corrs['feature_idx'].apply(lambda x: f"Photon_{x}")
    
    # Sort by absolute correlation
    e_corrs['abs_corr'] = np.abs(e_corrs['correlation'])
    p_corrs['abs_corr'] = np.abs(p_corrs['correlation'])
    e_corrs = e_corrs.sort_values('abs_corr', ascending=False)
    p_corrs = p_corrs.sort_values('abs_corr', ascending=False)
    
    # Plot electron correlations
    plt.figure(figsize=(12, 8))
    ax = sns.barplot(x='feature_name', y='correlation', data=e_corrs)
    plt.title('Correlation Between Anomaly Score and Electron Features')
    plt.xticks(rotation=90)
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.savefig('electron_feature_correlations.png', dpi=300)
    plt.show()
    
    # Plot photon correlations
    plt.figure(figsize=(12, 8))
    ax = sns.barplot(x='feature_name', y='correlation', data=p_corrs)
    plt.title('Correlation Between Anomaly Score and Photon Features')
    plt.xticks(rotation=90)
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.savefig('photon_feature_correlations.png', dpi=300)
    plt.show()
    
    # Print top correlations
    print("\nTop electron feature correlations:")
    for _, row in e_corrs.iloc[:10].iterrows():
        print(f"  {row['feature_name']} (idx {row['feature_idx']}): {row['correlation']:.4f} (p={row['p_value']:.4e})")
    
    print("\nTop photon feature correlations:")
    for _, row in p_corrs.iloc[:10].iterrows():
        print(f"  {row['feature_name']} (idx {row['feature_idx']}): {row['correlation']:.4f} (p={row['p_value']:.4e})")
    
    return e_corrs, p_corrs

# Define feature names (from README)
electron_features_list = [
    'electron_E', 'electron_pt', 'electron_eta', 'electron_phi',
    'electron_time', 'electron_d0', 'electron_z0', 'electron_dpt',
    'electron_nPIX', 'electron_nMissingLayers', 
    'electron_chi2_over_nDoF', 'electron_f1', 'electron_f3', 'electron_z'
]

photon_features_list = [
    'photon_E', 'photon_pt', 'photon_eta', 'photon_phi',
    'photon_time', 'photon_maxEcell_E', 'photon_f1', 'photon_f3', 
    'photon_r1', 'photon_r2', 'photon_etas1', 'photon_phis1', 'photon_z'
]

# %%
# Main execution
# 1. Calculate correlations
corr_results = calculate_feature_correlations(all_scores, 
                                             np.concatenate([test_electron_features, signal_electron_features]), 
                                             np.concatenate([test_photon_features, signal_photon_features]), 
                                             method='spearman')

# 2. Plot correlation results
e_corrs, p_corrs = plot_correlation_results(corr_results, 
                                           electron_features_list, 
                                           photon_features_list)
# Out:
# Top electron feature correlations:
#   electron_E (idx 0): 0.8123 (p=0.0000e+00)
#   electron_chi2_over_nDoF (idx 10): 0.8106 (p=0.0000e+00)
#   electron_pt (idx 1): 0.8066 (p=0.0000e+00)
#   electron_f1 (idx 11): 0.7404 (p=0.0000e+00)
#   electron_f3 (idx 12): 0.6661 (p=0.0000e+00)
#   electron_nPIX (idx 8): 0.6077 (p=0.0000e+00)
#   electron_nMissingLayers (idx 9): 0.3805 (p=0.0000e+00)
#   electron_time (idx 4): 0.2183 (p=0.0000e+00)
#   electron_dpt (idx 7): -0.1829 (p=0.0000e+00)
#   electron_z (idx 13): 0.0203 (p=1.3270e-197)
#
# Top photon feature correlations:
#   photon_r2 (idx 9): -0.4543 (p=0.0000e+00)
#   photon_r1 (idx 8): -0.4537 (p=0.0000e+00)
#   photon_f1 (idx 6): -0.4414 (p=0.0000e+00)
#   photon_E (idx 0): -0.4176 (p=0.0000e+00)
#   photon_f3 (idx 7): -0.3971 (p=0.0000e+00)
#   photon_phi (idx 3): -0.3826 (p=0.0000e+00)
#   photon_eta (idx 2): -0.3789 (p=0.0000e+00)
#   photon_maxEcell_E (idx 5): -0.3679 (p=0.0000e+00)
#   photon_pt (idx 1): -0.3675 (p=0.0000e+00)
#   photon_time (idx 4): 0.1120 (p=0.0000e+00)

# %%
def plot_electron_pt_distributions(e_feats, background_mask):
    """
    Create 1D histograms of pT for all 4 electrons in background events.
    
    Parameters:
    -----------
    e_feats: Electron features array [events, electrons, features]
    background_mask: Boolean mask for background events
    """
    # PT index in feature arrays
    pt_idx = 1  # Electron pt is at index 1
    
    # Create a figure with 4 subplots (one for each electron)
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    axes = axes.flatten()  # Flatten for easier indexing
    
    # Plot PT distribution for each electron
    for i in range(4):
        # Extract pt for the i-th electron in each event
        e_pt = e_feats[background_mask, i, pt_idx]
        
        # Filter out events where this electron doesn't exist (energy = 0)
        valid_mask = e_feats[background_mask, i, 0] > 0  # Energy > 0
        valid_e_pt = e_pt[valid_mask]
        
        # Only plot if we have enough data points
        if len(valid_e_pt) > 10:
            # Plot histogram
            axes[i].hist(valid_e_pt, bins=50, alpha=0.75, color='blue')
            
            # Calculate and show basic statistics
            mean_pt = np.mean(valid_e_pt)
            median_pt = np.median(valid_e_pt)
            std_pt = np.std(valid_e_pt)
            
            # Electron label based on index
            if i == 0:
                electron_label = "Leading Electron"
            elif i == 1:
                electron_label = "Sub-leading Electron"
            elif i == 2:
                electron_label = "Third Electron"
            else:
                electron_label = "Fourth Electron"
                
            axes[i].set_xlabel('Transverse Momentum (pT)')
            axes[i].set_ylabel('Count')
            axes[i].set_title(f'{electron_label} pT Distribution\nMean: {mean_pt:.2f}, Median: {median_pt:.2f}, Std: {std_pt:.2f}')
            axes[i].grid(alpha=0.3)
            
            # Add count of valid events
            axes[i].text(0.95, 0.95, f'Events: {len(valid_e_pt)}',
                       transform=axes[i].transAxes, 
                       horizontalalignment='right',
                       verticalalignment='top',
                       bbox=dict(boxstyle='round', facecolor='white', alpha=0.7))
            
            # Optional: set log scale for y-axis
            axes[i].set_yscale('log')
        else:
            axes[i].text(0.5, 0.5, "Insufficient data", 
                       horizontalalignment='center', verticalalignment='center',
                       transform=axes[i].transAxes)
    
    plt.tight_layout()
    plt.savefig('electron_pt_distributions.png', dpi=300)
    plt.show()

# Call the function
background_mask = all_labels == 0  # Get only background events

plot_electron_pt_distributions(
    np.concatenate([test_electron_features, signal_electron_features]),
    background_mask
)
